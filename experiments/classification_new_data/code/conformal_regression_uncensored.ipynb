# %%
import pandas as pd
from constants import DATA_PATH, EOS_FILE, SENTINEL_FILE

sentinel = pd.read_csv(DATA_PATH / SENTINEL_FILE)
eos = pd.read_csv(DATA_PATH / EOS_FILE)

# %%
sentinel = sentinel[sentinel['SM1 (%)'] != 50]
eos = eos[eos['SM1 (%)'] != 50]

# %%
from constants import X_cols_eos, X_cols_sentinel, y_col

X_sentinel = sentinel[X_cols_sentinel].values
X_eos = eos[X_cols_eos].values

y_sentinel = sentinel[y_col].values
y_eos = eos[y_col].values

# %%
from model_experiments import ConformalRegression


cr = ConformalRegression(X_eos, y_eos, "EOS-04")
cr.run_experiment()
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1778440066.454582 3756472 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1778440066.482261 3756472 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1778440067.251756 3756472 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# Results → /home/lmaosid/Desktop/major/experiments/classification_new_data/output/conformal_regression_uncensored
# Split sizes:
#   Train    - X: (1428, 5), y: 1428 (80.0%)
#   Conformal- X: (178, 5), y: 178 (10.0%)
#   Test     - X: (179, 5), y: 179 (10.0%)
#   Original data rows: 1785
# ==========Running QuantileRegressor===========
# ==========Running GradientBoostingRegressor===========
# INFO:root:The predictions are ill-sorted.
# ==========Running HistGradientBoostingRegressor===========
# ==========Running LGBMRegressor===========
# /home/lmaosid/Desktop/major/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /home/lmaosid/Desktop/major/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /home/lmaosid/Desktop/major/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /home/lmaosid/Desktop/major/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /home/lmaosid/Desktop/major/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /home/lmaosid/Desktop/major/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(

# %%
from model_experiments import ConformalRegression


cr = ConformalRegression(X_sentinel, y_sentinel, "Sentinel-1")
cr.run_experiment()
# Out:
# Results → /home/lmaosid/Desktop/major/experiments/classification_new_data/output/conformal_regression_uncensored
# Split sizes:
#   Train    - X: (1095, 5), y: 1095 (80.0%)
#   Conformal- X: (136, 5), y: 136 (9.9%)
#   Test     - X: (138, 5), y: 138 (10.1%)
#   Original data rows: 1369
# ==========Running QuantileRegressor===========
# ==========Running GradientBoostingRegressor===========
# ==========Running HistGradientBoostingRegressor===========
# ==========Running LGBMRegressor===========
# /home/lmaosid/Desktop/major/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /home/lmaosid/Desktop/major/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /home/lmaosid/Desktop/major/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /home/lmaosid/Desktop/major/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /home/lmaosid/Desktop/major/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /home/lmaosid/Desktop/major/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
