# %%
from constants import DATA_PATH
import pandas as pd


file = pd.ExcelFile(DATA_PATH / 'sentinel-1.xlsx')

# %%
dfs = [pd.read_excel(DATA_PATH / 'sentinel-1.xlsx', sheet_name=s) for s in file.sheet_names if s != 'UniqueCrops']

df = pd.concat(dfs).dropna()

df
# Out:
#       Sample Date & Time Sample Id (Grid)  Latitude (Centre of grid)  \
# 0    2022-06-18 00:00:00               1A                  22.526048
# 1    2022-06-18 00:00:00               1B                  22.525481
# 2    2022-06-18 00:00:00               1C                  22.525423
# 3    2022-06-18 00:00:00               1D                  22.525999
# 4    2022-06-18 00:00:00               1E                  22.525563
# ..                   ...              ...                        ...
# 135  2023-03-19 00:00:00              28A                  22.523697
# 136  2023-03-19 00:00:00              28B                  22.523710
# 137  2023-03-19 00:00:00              28C                  22.524262
# 138  2023-03-19 00:00:00              28D                  22.524252
# 139  2023-03-19 00:00:00              28E                  22.524049
#
#      Longitude (Centre of grid)   VH-pol    VV-pol  SM1 (%)     Crop Name
# 0                     72.765011 -19.3557 -13.54610      4.6        Fallow
# 1                     72.765028 -17.1605 -10.46910      7.2  Pearl Millet
# 2                     72.765663 -17.8729  -9.98927      6.4        Fallow
# 3                     72.765663 -17.7906 -11.93460      9.6         Lemon
# 4                     72.765399 -17.3646 -10.73270      3.9        Fallow
# ..                          ...      ...       ...      ...           ...
# 135                   72.767969 -16.7871 -11.17010     50.0         Wheat
# 136                   72.768582 -17.2167 -12.15740     50.0         Wheat
# 137                   72.768629 -17.7785 -10.37820     50.0       Tobacco
# 138                   72.767989 -16.6607 -10.62890     50.0       Tobacco
# 139                   72.768361 -17.4057 -10.62080     50.0        Strobe
#
# [1818 rows x 8 columns]

# %%
import seaborn as sns

sns.boxplot(df['SM1 (%)']);

# %%
df.sort_values(by='SM1 (%)', ascending=False)
# Out:
#       Sample Date & Time Sample Id (Grid)  Latitude (Centre of grid)  \
# 91   2023-02-11 00:00:00              19B                  22.505581
# 22   2023-01-30 00:00:00               5C                  22.527168
# 2    2022-09-20 00:00:00               1C                  22.525423
# 42   2023-02-11 00:00:00               9C                  22.528473
# 17   2022-08-27 00:00:00               4C                  22.525355
# ..                   ...              ...                        ...
# 30   2022-12-13 00:00:00               7A                  22.527958
# 96   2022-11-19 00:00:00              20B                  22.504650
# 115  2022-06-18 00:00:00              24A                  22.514666
# 90   2022-11-19 00:00:00              19A                  22.505576
# 33   2022-12-13 00:00:00               7D                  22.527949
#
#      Longitude (Centre of grid)   VH-pol    VV-pol  SM1 (%) Crop Name
# 91                    72.764064 -15.5062  -9.85398    283.0     Wheat
# 22                    72.759822 -16.5729 -11.91910     56.4     Wheat
# 2                     72.765663 -15.2878 -11.53430     54.7     Paddy
# 42                    72.747142 -15.6903 -10.08190     53.8     Wheat
# 17                    72.760222 -15.2550 -10.84050     52.5     Paddy
# ..                          ...      ...       ...      ...       ...
# 30                    72.750395 -18.1225 -11.24840      1.4    Fallow
# 96                    72.763111 -18.4282 -11.39890      1.4    Fallow
# 115                   72.762935 -18.6002 -11.19860      1.3    Fallow
# 90                    72.763430 -16.4145 -10.40410      1.2    Fallow
# 33                    72.751069 -16.8363 -11.63820      1.2    Fallow
#
# [1818 rows x 8 columns]

# %%
df = df[(df['SM1 (%)'] > 0) & (df['SM1 (%)'] <= 60)]

sns.boxplot(df['SM1 (%)']);

# %%
sns.histplot(df['SM1 (%)']);

# %%
df = df.assign(label=pd.qcut(df['SM1 (%)'], q=4, retbins=False, labels=['Low', 'Medium', 'High', 'Very High']))

# %%
df['Sample Date & Time'].unique()
# Out:
# array([Timestamp('2022-06-18 00:00:00'), Timestamp('2022-06-28 00:00:00'),
#        Timestamp('2022-07-22 00:00:00'), Timestamp('2022-08-27 00:00:00'),
#        Timestamp('2022-09-08 00:00:00'), Timestamp('2022-09-20 00:00:00'),
#        'WQ3E', datetime.datetime(2022, 10, 14, 0, 0),
#        Timestamp('2022-11-19 00:00:00'), Timestamp('2022-12-13 00:00:00'),
#        Timestamp('2023-01-18 00:00:00'), Timestamp('2023-01-30 00:00:00'),
#        Timestamp('2023-02-11 00:00:00'), Timestamp('2023-03-07 00:00:00'),
#        Timestamp('2023-03-19 00:00:00')], dtype=object)

# %%
df = df[df['Sample Date & Time'] != 'WQ3E']

# %%
file.sheet_names
# Out:
# ['16-06-2022',
#  '28-06-2022',
#  '22-07-2022',
#  '27-08-2022',
#  '08-09-2022',
#  '20-09-2022',
#  '14-10-2022',
#  '19-11-2022 ',
#  '13-12-2022',
#  '18-01-2023',
#  '30-01-2023',
#  '11-02-2023 ',
#  '07-03-2023',
#  '19-03-2023',
#  'UniqueCrops']

# %%
for ts in df['Sample Date & Time'].unique():
    print(ts)
# Out:
# 2022-06-18 00:00:00
# 2022-06-28 00:00:00
# 2022-07-22 00:00:00
# 2022-08-27 00:00:00
# 2022-09-08 00:00:00
# 2022-09-20 00:00:00
# 2022-10-14 00:00:00
# 2022-11-19 00:00:00
# 2022-12-13 00:00:00
# 2023-01-18 00:00:00
# 2023-01-30 00:00:00
# 2023-02-11 00:00:00
# 2023-03-07 00:00:00
# 2023-03-19 00:00:00

# %%
import matplotlib.pyplot as plt

unique_timestamps = sorted(df['Sample Date & Time'].unique())
n_timestamps = len(unique_timestamps)

print(f"Found {n_timestamps} unique timestamps. Setting up plot grid...")

ncols = 3
nrows = (n_timestamps + ncols - 1) // ncols

fig, axes = plt.subplots(nrows=nrows, ncols=ncols, figsize=(ncols * 5, nrows * 4))

axes_flat = axes.flatten()

print("Generating subplots...")
for i, ts in enumerate(unique_timestamps):
    ax = axes_flat[i] # Get the current subplot
    
    df_timestamp = df[df['Sample Date & Time'] == ts]
    
    sm_values = df_timestamp['SM1 (%)']
    
    sm_plottable = sm_values.sort_values().reset_index(drop=True)
    
    ax.plot(sm_plottable.index, sm_plottable.values, marker='.', linestyle='-')
    
    ax.set_title(f"{pd.to_datetime(ts).strftime('%B %d, %Y')}", fontsize=10)
    ax.set_xlabel("Sorted Index")
    ax.set_ylabel("SM1 (%)")
    ax.grid(True)

for j in range(n_timestamps, nrows * ncols):
    axes_flat[j].axis('off')

fig.suptitle('Sorted SM1 (%) Distribution per Timestamp', fontsize=16)

fig.tight_layout(rect=[0, 0.03, 1, 0.96]) # Adjust rect to make space for suptitle

plt.show()
# Out:
# Found 14 unique timestamps. Setting up plot grid...
# Generating subplots...

# %%
plt.figure(figsize=(20, 8))
sns.boxplot(data=df.sort_values(by='SM1 (%)'), y='SM1 (%)', hue='Crop Name', palette='bright')
# Out:
# <Axes: ylabel='SM1 (%)'>

# %%
plt.figure(figsize=(10, 8))
ax = sns.countplot(data=df, x='Crop Name')
ax.bar_label(ax.containers[0])
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(10, 8))
ax = sns.countplot(data=df, x='label')
ax.bar_label(ax.containers[0])
plt.xticks(rotation=90)
plt.show()

# %%
df
# Out:
#       Sample Date & Time Sample Id (Grid)  Latitude (Centre of grid)  \
# 0    2022-06-18 00:00:00               1A                  22.526048
# 1    2022-06-18 00:00:00               1B                  22.525481
# 2    2022-06-18 00:00:00               1C                  22.525423
# 3    2022-06-18 00:00:00               1D                  22.525999
# 4    2022-06-18 00:00:00               1E                  22.525563
# ..                   ...              ...                        ...
# 135  2023-03-19 00:00:00              28A                  22.523697
# 136  2023-03-19 00:00:00              28B                  22.523710
# 137  2023-03-19 00:00:00              28C                  22.524262
# 138  2023-03-19 00:00:00              28D                  22.524252
# 139  2023-03-19 00:00:00              28E                  22.524049
#
#      Longitude (Centre of grid)   VH-pol    VV-pol  SM1 (%)     Crop Name  \
# 0                     72.765011 -19.3557 -13.54610      4.6        Fallow
# 1                     72.765028 -17.1605 -10.46910      7.2  Pearl Millet
# 2                     72.765663 -17.8729  -9.98927      6.4        Fallow
# 3                     72.765663 -17.7906 -11.93460      9.6         Lemon
# 4                     72.765399 -17.3646 -10.73270      3.9        Fallow
# ..                          ...      ...       ...      ...           ...
# 135                   72.767969 -16.7871 -11.17010     50.0         Wheat
# 136                   72.768582 -17.2167 -12.15740     50.0         Wheat
# 137                   72.768629 -17.7785 -10.37820     50.0       Tobacco
# 138                   72.767989 -16.6607 -10.62890     50.0       Tobacco
# 139                   72.768361 -17.4057 -10.62080     50.0        Strobe
#
#          label
# 0          Low
# 1          Low
# 2          Low
# 3          Low
# 4          Low
# ..         ...
# 135  Very High
# 136  Very High
# 137  Very High
# 138  Very High
# 139  Very High
#
# [1816 rows x 9 columns]

# %%
df[['VH-pol', 'VV-pol', 'SM1 (%)', 'Crop Name', 'label']].to_csv(DATA_PATH / 'sentinel-1-processed.csv', index=False)

# %%
from constants import EOS_FILE, SENTINEL_FILE, DATA_PATH
import pandas as pd

pd.read_csv(DATA_PATH / SENTINEL_FILE)
# Out:
#        VH-pol    VV-pol  cross_pol_ratio     month_sin     month_cos  \
# 0    -19.3557 -13.54610         -5.80960  1.224647e-16 -1.000000e+00
# 1    -17.1605 -10.46910         -6.69140  1.224647e-16 -1.000000e+00
# 2    -17.8729  -9.98927         -7.88363  1.224647e-16 -1.000000e+00
# 3    -17.7906 -11.93460         -5.85600  1.224647e-16 -1.000000e+00
# 4    -17.3646 -10.73270         -6.63190  1.224647e-16 -1.000000e+00
# ...       ...       ...              ...           ...           ...
# 1811 -16.7871 -11.17010         -5.61700  1.000000e+00  6.123234e-17
# 1812 -17.2167 -12.15740         -5.05930  1.000000e+00  6.123234e-17
# 1813 -17.7785 -10.37820         -7.40030  1.000000e+00  6.123234e-17
# 1814 -16.6607 -10.62890         -6.03180  1.000000e+00  6.123234e-17
# 1815 -17.4057 -10.62080         -6.78490  1.000000e+00  6.123234e-17
#
#       crop_encoded  SM1 (%)     Crop Name      label
# 0                2      4.6        Fallow        Low
# 1               13      7.2  Pearl Millet        Low
# 2                2      6.4        Fallow        Low
# 3                7      9.6         Lemon        Low
# 4                2      3.9        Fallow        Low
# ...            ...      ...           ...        ...
# 1811            19     50.0         Wheat  Very High
# 1812            19     50.0         Wheat  Very High
# 1813            16     50.0       Tobacco  Very High
# 1814            16     50.0       Tobacco  Very High
# 1815            15     50.0        Strobe  Very High
#
# [1816 rows x 9 columns]
