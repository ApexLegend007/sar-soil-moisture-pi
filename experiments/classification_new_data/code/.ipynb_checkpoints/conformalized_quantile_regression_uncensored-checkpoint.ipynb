# %%
import pandas as pd
from constants import DATA_PATH, EOS_FILE, SENTINEL_FILE

sentinel = pd.read_csv(DATA_PATH / SENTINEL_FILE)
eos = pd.read_csv(DATA_PATH / EOS_FILE)

sentinel = sentinel[sentinel['SM1 (%)'] != 50]
eos = eos[eos['SM1 (%)'] != 50]
from constants import X_cols_eos, X_cols_sentinel, y_col

X_sentinel = sentinel[X_cols_sentinel].values
X_eos = eos[X_cols_eos].values

y_sentinel = sentinel[y_col].values
y_eos = eos[y_col].values

# %%
n_features = X_eos.shape[1]

import tensorflow as tf

models = {
#     "16, 1": tf.keras.Sequential([
#     # Input layer
#     tf.keras.Input(shape=(n_features, )),
#     tf.keras.layers.Dense(16, activation='relu'),
#     tf.keras.layers.Dense(1)
# ]),
#     "8, 1": tf.keras.Sequential([
#     # Input layer
#     tf.keras.Input(shape=(n_features, )),
#     tf.keras.layers.Dense(8, activation='relu'),
#     tf.keras.layers.Dense(1)
# ]),
#     "2, 1": tf.keras.Sequential([
#     # Input layer
#     tf.keras.Input(shape=(n_features, )),
#     tf.keras.layers.Dense(2, activation='relu'),
#     tf.keras.layers.Dense(1)
# ]),
#     "4, 1": tf.keras.Sequential([
#     # Input layer
#     tf.keras.Input(shape=(n_features, )),
#     tf.keras.layers.Dense(4, activation='relu'),
#     tf.keras.layers.Dense(1)
# ]),
#     "8, 4, 2, 1": tf.keras.Sequential([
#     # Input layer
#     tf.keras.Input(shape=(n_features, )),
#     tf.keras.layers.Dense(8, activation='relu'),
#     tf.keras.layers.Dense(4, activation='relu'),
#     tf.keras.layers.Dense(2, activation='relu'),
#     tf.keras.layers.Dense(1)
# ]),
    "16, Dropout, 8, Dropout": tf.keras.Sequential([
    # Input layer
    tf.keras.Input(shape=(n_features, )),
    tf.keras.layers.Dense(16, activation='relu'),
    tf.keras.layers.Dropout(0.09),
    tf.keras.layers.Dense(8, activation='relu'),
    tf.keras.layers.Dropout(0.09),
    tf.keras.layers.Dense(1)
]),
    "16, Dropout": tf.keras.Sequential([
    # Input layer
    tf.keras.Input(shape=(n_features, )),
    tf.keras.layers.Dense(16, activation='relu'),
    tf.keras.layers.Dropout(0.1),
    tf.keras.layers.Dense(1)
])
}

# %%
from model_experiments import ConformalizedQuantileExperiment

results_eos = {}

tf.keras.backend.clear_session()

ae = ConformalizedQuantileExperiment(X_eos, y_eos, satellite='EOS-04')
results = ae.run_experiment(models["16, Dropout, 8, Dropout"])

results
# Out:
# WARNING:tensorflow:From C:\Users\am133\OneDrive\Desktop\major\.claude\worktrees\happy-ellis-de3ea5\.venv\Lib\site-packages\keras\src\backend\common\global_state.py:82: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
# Results → C:\Users\am133\OneDrive\Desktop\major\.claude\worktrees\happy-ellis-de3ea5\experiments\classification_new_data\output\pi_estimation_uncensored
# Results → C:\Users\am133\OneDrive\Desktop\major\.claude\worktrees\happy-ellis-de3ea5\experiments\classification_new_data\output\conformal_results_uncensored
#
# --- Running SVM Split Conformal (SVR) ---
#   > Split Conformal Calibration constant (Q): 16.7759
#
# --- Running Linear CQR (QuantileRegressor) ---
#   > CQR Calibration constant (Q): -0.8067
#
# --- Running ANN CQR ---
# Epochs:   0%|          | 0/100 [00:00<?, ?epoch/s]
# Epochs:   0%|          | 0/100 [00:00<?, ?epoch/s, loss=17.7848, val_loss=16.2516]
# Epochs:   1%|          | 1/100 [00:00<01:06,  1.50epoch/s, loss=17.7848, val_loss=16.2516]
# Epochs:   1%|          | 1/100 [00:00<01:06,  1.50epoch/s, loss=17.4418, val_loss=15.7295]
# Epochs:   2%|▏         | 2/100 [00:00<00:33,  2.94epoch/s, loss=17.4418, val_loss=15.7295]
# Epochs:   2%|▏         | 2/100 [00:00<00:33,  2.94epoch/s, loss=16.4894, val_loss=14.3069]
# Epochs:   3%|▎         | 3/100 [00:00<00:33,  2.94epoch/s, loss=14.3872, val_loss=11.5665]
# Epochs:   4%|▍         | 4/100 [00:00<00:17,  5.36epoch/s, loss=14.3872, val_loss=11.5665]
# Epochs:   4%|▍         | 4/100 [00:01<00:17,  5.36epoch/s, loss=11.0031, val_loss=7.8065]
# Epochs:   5%|▌         | 5/100 [00:01<00:17,  5.36epoch/s, loss=7.3244, val_loss=4.3913]
# Epochs:   6%|▌         | 6/100 [00:01<00:13,  7.12epoch/s, loss=7.3244, val_loss=4.3913]
# Epochs:   6%|▌         | 6/100 [00:01<00:13,  7.12epoch/s, loss=4.2175, val_loss=2.0905]
# Epochs:   7%|▋         | 7/100 [00:01<00:12,  7.68epoch/s, loss=4.2175, val_loss=2.0905]
# Epochs:   7%|▋         | 7/100 [00:01<00:12,  7.68epoch/s, loss=2.3859, val_loss=0.9231]
# Epochs:   8%|▊         | 8/100 [00:01<00:11,  7.68epoch/s, loss=1.4747, val_loss=0.6220]
# Epochs:   9%|▉         | 9/100 [00:01<00:10,  9.03epoch/s, loss=1.4747, val_loss=0.6220]
# Epochs:   9%|▉         | 9/100 [00:01<00:10,  9.03epoch/s, loss=1.0800, val_loss=0.5672]
# Epochs:  10%|█         | 10/100 [00:01<00:09,  9.03epoch/s, loss=1.0288, val_loss=0.5646]
# Epochs:  11%|█         | 11/100 [00:01<00:09,  9.53epoch/s, loss=1.0288, val_loss=0.5646]
# Epochs:  11%|█         | 11/100 [00:01<00:09,  9.53epoch/s, loss=0.9387, val_loss=0.5824]
# Epochs:  12%|█▏        | 12/100 [00:01<00:09,  9.53epoch/s, loss=0.8481, val_loss=0.5950]
# Epochs:  13%|█▎        | 13/100 [00:01<00:08, 10.11epoch/s, loss=0.8481, val_loss=0.5950]
# Epochs:  13%|█▎        | 13/100 [00:01<00:08, 10.11epoch/s, loss=0.8361, val_loss=0.6091]
# Epochs:  14%|█▍        | 14/100 [00:02<00:08, 10.11epoch/s, loss=0.7555, val_loss=0.6091]
# Epochs:  15%|█▌        | 15/100 [00:02<00:09,  9.01epoch/s, loss=0.7555, val_loss=0.6091]
# Epochs:  15%|█▌        | 15/100 [00:02<00:09,  9.01epoch/s, loss=0.8302, val_loss=0.6217]
# Epochs:  16%|█▌        | 16/100 [00:02<00:09,  9.01epoch/s, loss=0.8454, val_loss=0.6219]
# Epochs:  17%|█▋        | 17/100 [00:02<00:08,  9.67epoch/s, loss=0.8454, val_loss=0.6219]
# Epochs:  17%|█▋        | 17/100 [00:02<00:08,  9.67epoch/s, loss=0.7953, val_loss=0.6271]
# Epochs:  18%|█▊        | 18/100 [00:02<00:08,  9.67epoch/s, loss=0.8347, val_loss=0.6348]
# Epochs:  19%|█▉        | 19/100 [00:02<00:08,  9.24epoch/s, loss=0.8347, val_loss=0.6348]
# Epochs:  19%|█▉        | 19/100 [00:02<00:08,  9.24epoch/s, loss=0.8682, val_loss=0.6392]
# Epochs:  20%|██        | 20/100 [00:02<00:08,  9.24epoch/s, loss=0.8966, val_loss=0.6452]
# Epochs:  21%|██        | 21/100 [00:02<00:08,  9.59epoch/s, loss=0.8966, val_loss=0.6452]
# Epochs:  21%|██        | 21/100 [00:02<00:09,  7.91epoch/s, loss=0.8966, val_loss=0.6452]
# Epochs:   0%|          | 0/100 [00:00<?, ?epoch/s]
# Epochs:   0%|          | 0/100 [00:00<?, ?epoch/s, loss=0.4421, val_loss=0.3995]
# Epochs:   1%|          | 1/100 [00:00<00:59,  1.66epoch/s, loss=0.4421, val_loss=0.3995]
# Epochs:   1%|          | 1/100 [00:00<00:59,  1.66epoch/s, loss=0.4239, val_loss=0.3779]
# Epochs:   2%|▏         | 2/100 [00:00<00:59,  1.66epoch/s, loss=0.4034, val_loss=0.3553]
# Epochs:   3%|▎         | 3/100 [00:00<00:21,  4.51epoch/s, loss=0.4034, val_loss=0.3553]
# Epochs:   3%|▎         | 3/100 [00:00<00:21,  4.51epoch/s, loss=0.3912, val_loss=0.3484]
# Epochs:   4%|▍         | 4/100 [00:00<00:17,  5.57epoch/s, loss=0.3912, val_loss=0.3484]
# Epochs:   4%|▍         | 4/100 [00:00<00:17,  5.57epoch/s, loss=0.3953, val_loss=0.3474]
# Epochs:   5%|▌         | 5/100 [00:01<00:17,  5.57epoch/s, loss=0.3948, val_loss=0.3467]
# Epochs:   6%|▌         | 6/100 [00:01<00:12,  7.37epoch/s, loss=0.3948, val_loss=0.3467]
# Epochs:   6%|▌         | 6/100 [00:01<00:12,  7.37epoch/s, loss=0.3910, val_loss=0.3449]
# Epochs:   7%|▋         | 7/100 [00:01<00:12,  7.37epoch/s, loss=0.3893, val_loss=0.3453]
# Epochs:   8%|▊         | 8/100 [00:01<00:10,  8.41epoch/s, loss=0.3893, val_loss=0.3453]
# Epochs:   8%|▊         | 8/100 [00:01<00:10,  8.41epoch/s, loss=0.3935, val_loss=0.3417]
# Epochs:   9%|▉         | 9/100 [00:01<00:10,  8.41epoch/s, loss=0.3873, val_loss=0.3406]
# Epochs:  10%|█         | 10/100 [00:01<00:10,  8.85epoch/s, loss=0.3873, val_loss=0.3406]
# Epochs:  10%|█         | 10/100 [00:01<00:10,  8.85epoch/s, loss=0.3893, val_loss=0.3400]
# Epochs:  11%|█         | 11/100 [00:01<00:10,  8.85epoch/s, loss=0.3830, val_loss=0.3380]
# Epochs:  12%|█▏        | 12/100 [00:01<00:09,  9.37epoch/s, loss=0.3830, val_loss=0.3380]
# Epochs:  12%|█▏        | 12/100 [00:01<00:09,  9.37epoch/s, loss=0.3841, val_loss=0.3350]
# Epochs:  13%|█▎        | 13/100 [00:01<00:09,  9.37epoch/s, loss=0.3845, val_loss=0.3359]
# Epochs:  14%|█▍        | 14/100 [00:01<00:08,  9.98epoch/s, loss=0.3845, val_loss=0.3359]
# Epochs:  14%|█▍        | 14/100 [00:01<00:08,  9.98epoch/s, loss=0.3843, val_loss=0.3330]
# Epochs:  15%|█▌        | 15/100 [00:01<00:08,  9.98epoch/s, loss=0.3802, val_loss=0.3293]
# Epochs:  16%|█▌        | 16/100 [00:02<00:08, 10.15epoch/s, loss=0.3802, val_loss=0.3293]
# Epochs:  16%|█▌        | 16/100 [00:02<00:08, 10.15epoch/s, loss=0.3821, val_loss=0.3316]
# Epochs:  17%|█▋        | 17/100 [00:02<00:08, 10.15epoch/s, loss=0.3836, val_loss=0.3332]
# Epochs:  18%|█▊        | 18/100 [00:02<00:07, 10.51epoch/s, loss=0.3836, val_loss=0.3332]
# Epochs:  18%|█▊        | 18/100 [00:02<00:07, 10.51epoch/s, loss=0.3784, val_loss=0.3316]
# Epochs:  19%|█▉        | 19/100 [00:02<00:07, 10.51epoch/s, loss=0.3800, val_loss=0.3322]
# Epochs:  20%|██        | 20/100 [00:02<00:07, 10.79epoch/s, loss=0.3800, val_loss=0.3322]
# Epochs:  20%|██        | 20/100 [00:02<00:07, 10.79epoch/s, loss=0.3786, val_loss=0.3282]
# Epochs:  21%|██        | 21/100 [00:02<00:07, 10.79epoch/s, loss=0.3811, val_loss=0.3270]
# Epochs:  22%|██▏       | 22/100 [00:02<00:07, 10.70epoch/s, loss=0.3811, val_loss=0.3270]
# Epochs:  22%|██▏       | 22/100 [00:02<00:07, 10.70epoch/s, loss=0.3822, val_loss=0.3290]
# Epochs:  23%|██▎       | 23/100 [00:02<00:07, 10.70epoch/s, loss=0.3806, val_loss=0.3325]
# Epochs:  24%|██▍       | 24/100 [00:02<00:07, 10.65epoch/s, loss=0.3806, val_loss=0.3325]
# Epochs:  24%|██▍       | 24/100 [00:02<00:07, 10.65epoch/s, loss=0.3786, val_loss=0.3297]
# Epochs:  25%|██▌       | 25/100 [00:02<00:07, 10.65epoch/s, loss=0.3815, val_loss=0.3268]
# Epochs:  26%|██▌       | 26/100 [00:02<00:06, 10.88epoch/s, loss=0.3815, val_loss=0.3268]
# Epochs:  26%|██▌       | 26/100 [00:03<00:06, 10.88epoch/s, loss=0.3814, val_loss=0.3333]
# Epochs:  27%|██▋       | 27/100 [00:03<00:06, 10.88epoch/s, loss=0.3777, val_loss=0.3301]
# Epochs:  28%|██▊       | 28/100 [00:03<00:06, 11.04epoch/s, loss=0.3777, val_loss=0.3301]
# Epochs:  28%|██▊       | 28/100 [00:03<00:06, 11.04epoch/s, loss=0.3802, val_loss=0.3297]
# Epochs:  29%|██▉       | 29/100 [00:03<00:06, 11.04epoch/s, loss=0.3784, val_loss=0.3330]
# Epochs:  30%|███       | 30/100 [00:03<00:06, 10.87epoch/s, loss=0.3784, val_loss=0.3330]
# Epochs:  30%|███       | 30/100 [00:03<00:06, 10.87epoch/s, loss=0.3749, val_loss=0.3236]
# Epochs:  31%|███       | 31/100 [00:03<00:06, 10.87epoch/s, loss=0.3822, val_loss=0.3261]
# Epochs:  32%|███▏      | 32/100 [00:03<00:06, 10.77epoch/s, loss=0.3822, val_loss=0.3261]
# Epochs:  32%|███▏      | 32/100 [00:03<00:06, 10.77epoch/s, loss=0.3786, val_loss=0.3298]
# Epochs:  33%|███▎      | 33/100 [00:03<00:06, 10.77epoch/s, loss=0.3779, val_loss=0.3272]
# Epochs:  34%|███▍      | 34/100 [00:03<00:06, 10.97epoch/s, loss=0.3779, val_loss=0.3272]
# Epochs:  34%|███▍      | 34/100 [00:03<00:06, 10.97epoch/s, loss=0.3779, val_loss=0.3278]
# Epochs:  35%|███▌      | 35/100 [00:03<00:05, 10.97epoch/s, loss=0.3803, val_loss=0.3280]
# Epochs:  36%|███▌      | 36/100 [00:03<00:05, 11.12epoch/s, loss=0.3803, val_loss=0.3280]
# Epochs:  36%|███▌      | 36/100 [00:03<00:05, 11.12epoch/s, loss=0.3770, val_loss=0.3276]
# Epochs:  37%|███▋      | 37/100 [00:03<00:05, 11.12epoch/s, loss=0.3798, val_loss=0.3290]
# Epochs:  38%|███▊      | 38/100 [00:03<00:05, 11.23epoch/s, loss=0.3798, val_loss=0.3290]
# Epochs:  38%|███▊      | 38/100 [00:04<00:05, 11.23epoch/s, loss=0.3741, val_loss=0.3272]
# Epochs:  39%|███▉      | 39/100 [00:04<00:05, 11.23epoch/s, loss=0.3774, val_loss=0.3255]
# Epochs:  40%|████      | 40/100 [00:04<00:05, 11.06epoch/s, loss=0.3774, val_loss=0.3255]
# Epochs:  40%|████      | 40/100 [00:04<00:05, 11.06epoch/s, loss=0.3737, val_loss=0.3246]
# Epochs:  41%|████      | 41/100 [00:04<00:06,  9.61epoch/s, loss=0.3737, val_loss=0.3246]
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
#   > CQR Calibration constant (Q): -0.7017
# Evaluating SVM_Split_Conformal...
# Evaluating Linear_CQR...
# Evaluating ANN_CQR...
# All Conformal Experiments Completed. Results saved to C:\Users\am133\OneDrive\Desktop\major\.claude\worktrees\happy-ellis-de3ea5\experiments\classification_new_data\output\conformal_results_uncensored\EOS-04_conformal_metrics.json
# {'SVM_Split_Conformal': {'PICP': 0.9050279329608939,
#   'MPIW': 33.55186842490495},
#  'Linear_CQR': {'PICP': 0.9329608938547486, 'MPIW': 40.6266666666666},
#  'ANN_CQR': {'PICP': 0.8938547486033519, 'MPIW': 31.574081335520614}}

# %%
from model_experiments import ConformalizedQuantileExperiment

results_eos = {}

tf.keras.backend.clear_session()

ae = ConformalizedQuantileExperiment(X_sentinel, y_sentinel, satellite='Sentinel-1')
results = ae.run_experiment(models["16, Dropout, 8, Dropout"])

results
# Out:
# Results → C:\Users\am133\OneDrive\Desktop\major\.claude\worktrees\happy-ellis-de3ea5\experiments\classification_new_data\output\pi_estimation_uncensored
# Results → C:\Users\am133\OneDrive\Desktop\major\.claude\worktrees\happy-ellis-de3ea5\experiments\classification_new_data\output\conformal_results_uncensored
#
# --- Running SVM Split Conformal (SVR) ---
#   > Split Conformal Calibration constant (Q): 20.5748
#
# --- Running Linear CQR (QuantileRegressor) ---
#   > CQR Calibration constant (Q): 1.6667
#
# --- Running ANN CQR ---
# Epochs:   0%|          | 0/100 [00:00<?, ?epoch/s]
# Epochs:   0%|          | 0/100 [00:00<?, ?epoch/s, loss=19.4250, val_loss=19.0341]
# Epochs:   1%|          | 1/100 [00:00<00:59,  1.66epoch/s, loss=19.4250, val_loss=19.0341]
# Epochs:   1%|          | 1/100 [00:00<00:59,  1.66epoch/s, loss=19.0898, val_loss=18.6247]
# Epochs:   2%|▏         | 2/100 [00:00<00:59,  1.66epoch/s, loss=18.5372, val_loss=17.9527]
# Epochs:   3%|▎         | 3/100 [00:00<00:21,  4.53epoch/s, loss=18.5372, val_loss=17.9527]
# Epochs:   3%|▎         | 3/100 [00:00<00:21,  4.53epoch/s, loss=17.6952, val_loss=16.9058]
# Epochs:   4%|▍         | 4/100 [00:00<00:21,  4.53epoch/s, loss=16.3742, val_loss=15.3865]
# Epochs:   5%|▌         | 5/100 [00:00<00:14,  6.57epoch/s, loss=16.3742, val_loss=15.3865]
# Epochs:   5%|▌         | 5/100 [00:01<00:14,  6.57epoch/s, loss=14.5159, val_loss=13.3396]
# Epochs:   6%|▌         | 6/100 [00:01<00:14,  6.57epoch/s, loss=12.1552, val_loss=10.9017]
# Epochs:   7%|▋         | 7/100 [00:01<00:11,  8.24epoch/s, loss=12.1552, val_loss=10.9017]
# Epochs:   7%|▋         | 7/100 [00:01<00:11,  8.24epoch/s, loss=9.4636, val_loss=8.2980]
# Epochs:   8%|▊         | 8/100 [00:01<00:11,  8.24epoch/s, loss=6.7968, val_loss=5.8905]
# Epochs:   9%|▉         | 9/100 [00:01<00:09,  9.21epoch/s, loss=6.7968, val_loss=5.8905]
# Epochs:   9%|▉         | 9/100 [00:01<00:09,  9.21epoch/s, loss=4.8900, val_loss=3.9955]
# Epochs:  10%|█         | 10/100 [00:01<00:09,  9.21epoch/s, loss=3.4297, val_loss=2.8277]
# Epochs:  11%|█         | 11/100 [00:01<00:08, 10.10epoch/s, loss=3.4297, val_loss=2.8277]
# Epochs:  11%|█         | 11/100 [00:01<00:08, 10.10epoch/s, loss=2.4831, val_loss=2.0628]
# Epochs:  12%|█▏        | 12/100 [00:01<00:08, 10.10epoch/s, loss=1.8283, val_loss=1.5966]
# Epochs:  13%|█▎        | 13/100 [00:01<00:07, 10.89epoch/s, loss=1.8283, val_loss=1.5966]
# Epochs:  13%|█▎        | 13/100 [00:01<00:07, 10.89epoch/s, loss=1.4374, val_loss=1.2500]
# Epochs:  14%|█▍        | 14/100 [00:01<00:07, 10.89epoch/s, loss=1.2181, val_loss=1.0519]
# Epochs:  15%|█▌        | 15/100 [00:01<00:08,  9.69epoch/s, loss=1.2181, val_loss=1.0519]
# Epochs:  15%|█▌        | 15/100 [00:01<00:08,  9.69epoch/s, loss=1.0749, val_loss=0.9500]
# Epochs:  16%|█▌        | 16/100 [00:02<00:08,  9.69epoch/s, loss=1.0899, val_loss=0.8639]
# Epochs:  17%|█▋        | 17/100 [00:02<00:07, 10.46epoch/s, loss=1.0899, val_loss=0.8639]
# Epochs:  17%|█▋        | 17/100 [00:02<00:07, 10.46epoch/s, loss=1.0783, val_loss=0.8142]
# Epochs:  18%|█▊        | 18/100 [00:02<00:07, 10.46epoch/s, loss=0.9298, val_loss=0.7814]
# Epochs:  19%|█▉        | 19/100 [00:02<00:07, 10.74epoch/s, loss=0.9298, val_loss=0.7814]
# Epochs:  19%|█▉        | 19/100 [00:02<00:07, 10.74epoch/s, loss=0.8775, val_loss=0.7610]
# Epochs:  20%|██        | 20/100 [00:02<00:07, 10.74epoch/s, loss=0.8833, val_loss=0.7420]
# Epochs:  21%|██        | 21/100 [00:02<00:07, 11.26epoch/s, loss=0.8833, val_loss=0.7420]
# Epochs:  21%|██        | 21/100 [00:02<00:07, 11.26epoch/s, loss=1.0229, val_loss=0.7181]
# Epochs:  22%|██▏       | 22/100 [00:02<00:06, 11.26epoch/s, loss=0.8486, val_loss=0.7050]
# Epochs:  23%|██▎       | 23/100 [00:02<00:06, 11.34epoch/s, loss=0.8486, val_loss=0.7050]
# Epochs:  23%|██▎       | 23/100 [00:02<00:06, 11.34epoch/s, loss=0.8096, val_loss=0.6996]
# Epochs:  24%|██▍       | 24/100 [00:02<00:06, 11.34epoch/s, loss=0.9153, val_loss=0.6959]
# Epochs:  25%|██▌       | 25/100 [00:02<00:06, 11.38epoch/s, loss=0.9153, val_loss=0.6959]
# Epochs:  25%|██▌       | 25/100 [00:02<00:06, 11.38epoch/s, loss=0.8826, val_loss=0.6941]
# Epochs:  26%|██▌       | 26/100 [00:02<00:06, 11.38epoch/s, loss=0.9001, val_loss=0.6921]
# Epochs:  27%|██▋       | 27/100 [00:02<00:06, 11.70epoch/s, loss=0.9001, val_loss=0.6921]
# Epochs:  27%|██▋       | 27/100 [00:02<00:06, 11.70epoch/s, loss=0.9419, val_loss=0.6909]
# Epochs:  28%|██▊       | 28/100 [00:03<00:06, 11.70epoch/s, loss=0.9454, val_loss=0.6889]
# Epochs:  29%|██▉       | 29/100 [00:03<00:06, 11.64epoch/s, loss=0.9454, val_loss=0.6889]
# Epochs:  29%|██▉       | 29/100 [00:03<00:06, 11.64epoch/s, loss=0.8507, val_loss=0.6880]
# Epochs:  30%|███       | 30/100 [00:03<00:06, 11.64epoch/s, loss=0.8325, val_loss=0.6875]
# Epochs:  31%|███       | 31/100 [00:03<00:05, 11.90epoch/s, loss=0.8325, val_loss=0.6875]
# Epochs:  31%|███       | 31/100 [00:03<00:05, 11.90epoch/s, loss=0.8848, val_loss=0.6868]
# Epochs:  32%|███▏      | 32/100 [00:03<00:05, 11.90epoch/s, loss=0.8964, val_loss=0.6859]
# Epochs:  33%|███▎      | 33/100 [00:03<00:05, 11.78epoch/s, loss=0.8964, val_loss=0.6859]
# Epochs:  33%|███▎      | 33/100 [00:03<00:05, 11.78epoch/s, loss=0.8950, val_loss=0.6863]
# Epochs:  34%|███▍      | 34/100 [00:03<00:05, 11.78epoch/s, loss=0.9186, val_loss=0.6864]
# Epochs:  35%|███▌      | 35/100 [00:03<00:05, 12.02epoch/s, loss=0.9186, val_loss=0.6864]
# Epochs:  35%|███▌      | 35/100 [00:03<00:05, 12.02epoch/s, loss=0.7507, val_loss=0.6862]
# Epochs:  36%|███▌      | 36/100 [00:03<00:05, 12.02epoch/s, loss=0.8794, val_loss=0.6861]
# Epochs:  37%|███▋      | 37/100 [00:03<00:05, 11.87epoch/s, loss=0.8794, val_loss=0.6861]
# Epochs:  37%|███▋      | 37/100 [00:03<00:05, 11.87epoch/s, loss=0.9102, val_loss=0.6891]
# Epochs:  38%|███▊      | 38/100 [00:03<00:05, 11.87epoch/s, loss=0.8406, val_loss=0.6892]
# Epochs:  39%|███▉      | 39/100 [00:03<00:05, 10.29epoch/s, loss=0.8406, val_loss=0.6892]
# Epochs:  39%|███▉      | 39/100 [00:04<00:05, 10.29epoch/s, loss=0.9504, val_loss=0.6898]
# Epochs:  40%|████      | 40/100 [00:04<00:05, 10.29epoch/s, loss=0.7986, val_loss=0.6888]
# Epochs:  41%|████      | 41/100 [00:04<00:05, 10.90epoch/s, loss=0.7986, val_loss=0.6888]
# Epochs:  41%|████      | 41/100 [00:04<00:05, 10.90epoch/s, loss=0.8292, val_loss=0.6896]
# Epochs:  42%|████▏     | 42/100 [00:04<00:05, 10.90epoch/s, loss=0.8865, val_loss=0.6922]
# Epochs:  43%|████▎     | 43/100 [00:04<00:05, 11.05epoch/s, loss=0.8865, val_loss=0.6922]
# Epochs:  43%|████▎     | 43/100 [00:04<00:05, 10.00epoch/s, loss=0.8865, val_loss=0.6922]
# Epochs:   0%|          | 0/100 [00:00<?, ?epoch/s]
# Epochs:   0%|          | 0/100 [00:00<?, ?epoch/s, loss=0.5057, val_loss=0.4979]
# Epochs:   1%|          | 1/100 [00:00<00:58,  1.70epoch/s, loss=0.5057, val_loss=0.4979]
# Epochs:   1%|          | 1/100 [00:00<00:58,  1.70epoch/s, loss=0.5023, val_loss=0.4936]
# Epochs:   2%|▏         | 2/100 [00:00<00:57,  1.70epoch/s, loss=0.4961, val_loss=0.4854]
# Epochs:   3%|▎         | 3/100 [00:00<00:21,  4.61epoch/s, loss=0.4961, val_loss=0.4854]
# Epochs:   3%|▎         | 3/100 [00:00<00:21,  4.61epoch/s, loss=0.4850, val_loss=0.4708]
# Epochs:   4%|▍         | 4/100 [00:00<00:20,  4.61epoch/s, loss=0.4673, val_loss=0.4555]
# Epochs:   5%|▌         | 5/100 [00:00<00:14,  6.66epoch/s, loss=0.4673, val_loss=0.4555]
# Epochs:   5%|▌         | 5/100 [00:01<00:14,  6.66epoch/s, loss=0.4465, val_loss=0.4655]
# Epochs:   6%|▌         | 6/100 [00:01<00:14,  6.66epoch/s, loss=0.4259, val_loss=0.4926]
# Epochs:   7%|▋         | 7/100 [00:01<00:11,  8.34epoch/s, loss=0.4259, val_loss=0.4926]
# Epochs:   7%|▋         | 7/100 [00:01<00:11,  8.34epoch/s, loss=0.4232, val_loss=0.4942]
# Epochs:   8%|▊         | 8/100 [00:01<00:11,  8.34epoch/s, loss=0.4288, val_loss=0.4801]
# Epochs:   9%|▉         | 9/100 [00:01<00:09,  9.29epoch/s, loss=0.4288, val_loss=0.4801]
# Epochs:   9%|▉         | 9/100 [00:01<00:09,  9.29epoch/s, loss=0.4247, val_loss=0.4906]
# Epochs:  10%|█         | 10/100 [00:01<00:09,  9.29epoch/s, loss=0.4215, val_loss=0.4884]
# Epochs:  11%|█         | 11/100 [00:01<00:08, 10.24epoch/s, loss=0.4215, val_loss=0.4884]
# Epochs:  11%|█         | 11/100 [00:01<00:08, 10.24epoch/s, loss=0.4212, val_loss=0.4840]
# Epochs:  12%|█▏        | 12/100 [00:01<00:08, 10.24epoch/s, loss=0.4256, val_loss=0.4762]
# Epochs:  13%|█▎        | 13/100 [00:01<00:09,  9.56epoch/s, loss=0.4256, val_loss=0.4762]
# Epochs:  13%|█▎        | 13/100 [00:01<00:09,  9.56epoch/s, loss=0.4218, val_loss=0.4797]
# Epochs:  14%|█▍        | 14/100 [00:01<00:08,  9.56epoch/s, loss=0.4167, val_loss=0.4829]
# Epochs:  15%|█▌        | 15/100 [00:01<00:08, 10.10epoch/s, loss=0.4167, val_loss=0.4829]
# Epochs:  15%|█▌        | 15/100 [00:01<00:10,  8.16epoch/s, loss=0.4167, val_loss=0.4829]
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# WARNING:tensorflow:5 out of the last 23 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000001A871F12F20> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
#   > CQR Calibration constant (Q): -0.1220
# Evaluating SVM_Split_Conformal...
# Evaluating Linear_CQR...
# Evaluating ANN_CQR...
# All Conformal Experiments Completed. Results saved to C:\Users\am133\OneDrive\Desktop\major\.claude\worktrees\happy-ellis-de3ea5\experiments\classification_new_data\output\conformal_results_uncensored\Sentinel-1_conformal_metrics.json
# {'SVM_Split_Conformal': {'PICP': 0.9562043795620438, 'MPIW': 41.1496499094842},
#  'Linear_CQR': {'PICP': 0.9781021897810219, 'MPIW': 45.93333333333334},
#  'ANN_CQR': {'PICP': 0.9854014598540146, 'MPIW': 43.69786604895209}}
