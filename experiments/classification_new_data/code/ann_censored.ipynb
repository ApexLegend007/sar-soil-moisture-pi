# %%
import pandas as pd
from constants import DATA_PATH, EOS_FILE, SENTINEL_FILE

sentinel = pd.read_csv(DATA_PATH / SENTINEL_FILE)
eos = pd.read_csv(DATA_PATH / EOS_FILE)

# %%
from constants import X_cols_eos, X_cols_sentinel, y_col

X_sentinel = sentinel[X_cols_sentinel].values
X_eos = eos[X_cols_eos].values

y_sentinel = sentinel[y_col].values
y_eos = eos[y_col].values

# %%
n_features = X_eos.shape[1]

import tensorflow as tf

models = {
    "16, 1": tf.keras.Sequential([
    # Input layer
    tf.keras.Input(shape=(n_features, )),
    tf.keras.layers.Dense(16, activation='relu'),
    tf.keras.layers.Dense(1)
]),
    "8, 1": tf.keras.Sequential([
    # Input layer
    tf.keras.Input(shape=(n_features, )),
    tf.keras.layers.Dense(8, activation='relu'),
    tf.keras.layers.Dense(1)
]),
    "2, 1": tf.keras.Sequential([
    # Input layer
    tf.keras.Input(shape=(n_features, )),
    tf.keras.layers.Dense(2, activation='relu'),
    tf.keras.layers.Dense(1)
]),
    "4, 1": tf.keras.Sequential([
    # Input layer
    tf.keras.Input(shape=(n_features, )),
    tf.keras.layers.Dense(4, activation='relu'),
    tf.keras.layers.Dense(1)
]),
    "8, 4, 2, 1": tf.keras.Sequential([
    # Input layer
    tf.keras.Input(shape=(n_features, )),
    tf.keras.layers.Dense(8, activation='relu'),
    tf.keras.layers.Dense(4, activation='relu'),
    tf.keras.layers.Dense(2, activation='relu'),
    tf.keras.layers.Dense(1)
]),
    "16, Dropout, 8, Dropout": tf.keras.Sequential([
    # Input layer
    tf.keras.Input(shape=(n_features, )),
    tf.keras.layers.Dense(16, activation='relu'),
    tf.keras.layers.Dropout(0.09),
    tf.keras.layers.Dense(8, activation='relu'),
    tf.keras.layers.Dropout(0.09),
    tf.keras.layers.Dense(1)
]),
    "16, Dropout": tf.keras.Sequential([
    # Input layer
    tf.keras.Input(shape=(n_features, )),
    tf.keras.layers.Dense(16, activation='relu'),
    tf.keras.layers.Dropout(0.1),
    tf.keras.layers.Dense(1)
])
}

# %%
from model_experiments import ANNExperiment

results_eos = {}

for model_string, model in models.items():
    print(f"========= {model_string} ========")
    tf.keras.backend.clear_session()

    ae = ANNExperiment(X_eos, y_eos, satellite='EOS-04', type='censored')
    results = ae.run_experiment(model, model_param_string=model_string)
    results_eos[model_string] = results
# Out:
# ========= 16, 1 ========
# WARNING:tensorflow:From C:\Users\am133\OneDrive\Desktop\major\.claude\worktrees\happy-ellis-de3ea5\.venv\Lib\site-packages\keras\src\backend\common\global_state.py:82: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
# Results → C:\Users\am133\OneDrive\Desktop\major\.claude\worktrees\happy-ellis-de3ea5\experiments\classification_new_data\output\ann_experiments_censored
# Test Loss (MSE): 119.5505
# Test MAE: 8.4942
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Additional Metrics:
# MSE: 119.5505
# R² Score: 0.4146
# ========= 8, 1 ========
# Results → C:\Users\am133\OneDrive\Desktop\major\.claude\worktrees\happy-ellis-de3ea5\experiments\classification_new_data\output\ann_experiments_censored
# Test Loss (MSE): 120.1140
# Test MAE: 8.5398
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Additional Metrics:
# MSE: 120.1140
# R² Score: 0.4119
# ========= 2, 1 ========
# Results → C:\Users\am133\OneDrive\Desktop\major\.claude\worktrees\happy-ellis-de3ea5\experiments\classification_new_data\output\ann_experiments_censored
# Test Loss (MSE): 123.5207
# Test MAE: 8.9420
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Additional Metrics:
# MSE: 123.5207
# R² Score: 0.3952
# ========= 4, 1 ========
# Results → C:\Users\am133\OneDrive\Desktop\major\.claude\worktrees\happy-ellis-de3ea5\experiments\classification_new_data\output\ann_experiments_censored
# Test Loss (MSE): 123.8247
# Test MAE: 8.9571
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Additional Metrics:
# MSE: 123.8247
# R² Score: 0.3937
# ========= 8, 4, 2, 1 ========
# Results → C:\Users\am133\OneDrive\Desktop\major\.claude\worktrees\happy-ellis-de3ea5\experiments\classification_new_data\output\ann_experiments_censored
# Test Loss (MSE): 119.2548
# Test MAE: 8.4938
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Additional Metrics:
# MSE: 119.2548
# R² Score: 0.4161
# ========= 16, Dropout, 8, Dropout ========
# Results → C:\Users\am133\OneDrive\Desktop\major\.claude\worktrees\happy-ellis-de3ea5\experiments\classification_new_data\output\ann_experiments_censored
# Test Loss (MSE): 118.6450
# Test MAE: 8.3197
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Additional Metrics:
# MSE: 118.6450
# R² Score: 0.4191
# ========= 16, Dropout ========
# Results → C:\Users\am133\OneDrive\Desktop\major\.claude\worktrees\happy-ellis-de3ea5\experiments\classification_new_data\output\ann_experiments_censored
# Test Loss (MSE): 119.3727
# Test MAE: 8.4937
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Additional Metrics:
# MSE: 119.3727
# R² Score: 0.4155

# %%
import json
from constants import OUTPUT_PATH

with open(OUTPUT_PATH / "ann_experiments_censored" / "EOS-04_metrics.json", "w") as f:
    json.dump(results_eos, f, indent=4)

# %%
from model_experiments import ANNExperiment

results_sentinel = {}

for model_string, model in models.items():
    print(f"========= {model_string} ========")
    tf.keras.backend.clear_session()

    ae = ANNExperiment(X_sentinel, y_sentinel, satellite='Sentinel-1', type='censored')
    results = ae.run_experiment(model, model_param_string=model_string)
    results_sentinel[model_string] = results
# Out:
# ========= 16, 1 ========
# Results → C:\Users\am133\OneDrive\Desktop\major\.claude\worktrees\happy-ellis-de3ea5\experiments\classification_new_data\output\ann_experiments_censored
# Test Loss (MSE): 185.6638
# Test MAE: 10.6337
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Additional Metrics:
# MSE: 185.6638
# R² Score: 0.2230
# ========= 8, 1 ========
# Results → C:\Users\am133\OneDrive\Desktop\major\.claude\worktrees\happy-ellis-de3ea5\experiments\classification_new_data\output\ann_experiments_censored
# Test Loss (MSE): 185.7423
# Test MAE: 10.6385
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Additional Metrics:
# MSE: 185.7423
# R² Score: 0.2227
# ========= 2, 1 ========
# Results → C:\Users\am133\OneDrive\Desktop\major\.claude\worktrees\happy-ellis-de3ea5\experiments\classification_new_data\output\ann_experiments_censored
# Test Loss (MSE): 186.7557
# Test MAE: 10.6506
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Additional Metrics:
# MSE: 186.7557
# R² Score: 0.2185
# ========= 4, 1 ========
# Results → C:\Users\am133\OneDrive\Desktop\major\.claude\worktrees\happy-ellis-de3ea5\experiments\classification_new_data\output\ann_experiments_censored
# Test Loss (MSE): 186.1023
# Test MAE: 10.6853
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Additional Metrics:
# MSE: 186.1023
# R² Score: 0.2212
# ========= 8, 4, 2, 1 ========
# Results → C:\Users\am133\OneDrive\Desktop\major\.claude\worktrees\happy-ellis-de3ea5\experiments\classification_new_data\output\ann_experiments_censored
# Test Loss (MSE): 186.9069
# Test MAE: 10.7340
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# Additional Metrics:
# MSE: 186.9069
# R² Score: 0.2178
# ========= 16, Dropout, 8, Dropout ========
# Results → C:\Users\am133\OneDrive\Desktop\major\.claude\worktrees\happy-ellis-de3ea5\experiments\classification_new_data\output\ann_experiments_censored
# Test Loss (MSE): 187.7968
# Test MAE: 10.5786
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# Additional Metrics:
# MSE: 187.7968
# R² Score: 0.2141
# ========= 16, Dropout ========
# Results → C:\Users\am133\OneDrive\Desktop\major\.claude\worktrees\happy-ellis-de3ea5\experiments\classification_new_data\output\ann_experiments_censored
# Test Loss (MSE): 186.2862
# Test MAE: 10.6732
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# Additional Metrics:
# MSE: 186.2862
# R² Score: 0.2204

# %%
import json
from constants import OUTPUT_PATH

with open(OUTPUT_PATH / "ann_experiments_censored" / "Sentinel-1_metrics.json", "w") as f:
    json.dump(results_sentinel, f, indent=4)
